# %% [markdown]
# # YOLO Detection Art Installation - Interactive Notebook
#
# This notebook demonstrates object detection using YOLO models with Supervision for visualization.

# %%
# Import required libraries
import cv2
import supervision as sv
from ultralytics import YOLO
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display, Image
import warnings
warnings.filterwarnings('ignore')

# %%
# Check versions
import ultralytics
print(f"Supervision: {sv.__version__}")
print(f"OpenCV: {cv2.__version__}")
print(f"Ultralytics: {ultralytics.__version__}")

# %% [markdown]
# ## Load a YOLO Model
#
# Choose from:
# - `yolo12n.pt` - Fastest, smallest
# - `yolov8n.pt` - YOLOv8 nano
# - `yolov8n-world.pt` - Open-vocabulary detection

# %%
# Load model (will download automatically on first use)
model = YOLO("yolo12n.pt")
print("Model loaded successfully!")
